# %%
import sys
sys.path.append('/home/olga/PycharmProjects/2-edu/monocular-motion-parallax/core')

from core.cylinder import Cylinder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 import sys
#       2 sys.path.append('/home/olga/PycharmProjects/2-edu/monocular-motion-parallax/core')
# ----> 4 from core.cylinder import Cylinder
#
# ModuleNotFoundError: No module named 'core'

# %%
cylinder = Cylinder(rho=5, z=(-10, 10))
cylinder.generate_random_points(60)
# Out:
# array([[-1.22048306,  4.84875459,  4.31908856],
#        [ 4.64129268, -1.85967801,  9.00859638],
#        [-4.73835081, -1.59625548, -1.52994672],
#        [ 3.23104126, -3.8158056 , -1.43005099],
#        [-4.1321859 ,  2.81514471,  3.88449102],
#        [-0.65285843, -4.95719435, -0.75971704],
#        [-1.04391747, -4.88980943, -8.24902288],
#        [ 4.97634264,  0.48581266, -8.54257655],
#        [ 4.92280623, -0.87520218,  6.95796947],
#        [ 2.99925418,  4.00055926,  7.81743548],
#        [ 2.86005948, -4.10122662, -6.30836679],
#        [ 1.71792738, -4.69560705, -6.82279204],
#        [ 4.8141297 ,  1.3506129 ,  2.06839162],
#        [ 4.4713537 ,  2.2376318 ,  2.99232186],
#        [ 4.98359562,  0.40469088,  6.61104299],
#        [-3.82836748, -3.21614714, -6.72787864],
#        [-0.81333411,  4.93340528,  2.60133124],
#        [ 0.58562774,  4.96558558, -5.62225862],
#        [ 4.38951509, -2.3941924 , -9.27193533],
#        [ 2.9499884 ,  4.0370247 , -3.83748623],
# ...
